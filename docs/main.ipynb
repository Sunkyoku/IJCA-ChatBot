# %%
import pandas as pd

# %%
#Configuração do pandas
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
#desativa todas as configurações realizadas no pandas
pd.reset_option('all')

# %%
ac = pd.read_csv('acidentes2025.csv',sep=';', index_col='id', encoding='latin-1')
dt = pd.read_csv('datatran2025.csv', sep=';', index_col='id', encoding='latin-1')

# %% [markdown]
# Tratamentos de dados

# %%
#Preenchimento de Células vazias
ac.fillna('Não Informado', inplace=True)
dt.fillna('Não Informado', inplace=True)

# %%
ac.isna().sum()
# Out:
# pesid                         0
# data_inversa                  0
# dia_semana                    0
# horario                       0
# uf                            0
# br                            0
# km                            0
# municipio                     0
# causa_acidente                0
# tipo_acidente                 0
# classificacao_acidente        7
# fase_dia                      0
# sentido_via                   0
# condicao_metereologica        0
# tipo_pista                    0
# tracado_via                   0
# uso_solo                      0
# id_veiculo                    0
# tipo_veiculo               5212
# marca                         0
# ano_fabricacao_veiculo        0
# tipo_envolvido            14325
# estado_fisico             14325
# idade                         0
# sexo                      14325
# ilesos                        0
# feridos_leves                 0
# feridos_graves                0
# mortos                        0
# ...

# %%
dt.isna().sum()
# Out:
# data_inversa               0
# dia_semana                 0
# horario                    0
# uf                         0
# br                         0
# km                         0
# municipio                  0
# causa_acidente             0
# tipo_acidente              0
# classificacao_acidente     1
# fase_dia                   0
# sentido_via                0
# condicao_metereologica     0
# tipo_pista                 0
# tracado_via                0
# uso_solo                   0
# pessoas                    0
# mortos                     0
# feridos_leves              0
# feridos_graves             0
# ilesos                     0
# ignorados                  0
# feridos                    0
# veiculos                   0
# latitude                   0
# longitude                  0
# regional                   2
# delegacia                 17
# uop                       29
# dtype: int64

# %%
#Novo data frame
df = ac.merge(dt, how='inner')
df.head(5)
# Out:
#      pesid data_inversa    dia_semana   horario  uf   br     km  \
# 0  1468136   2025-01-01  quarta-feira  12:23:00  RS  116    376
# 1  1467996   2025-01-01  quarta-feira  18:40:00  MG  116  708,5
# 2  1468156   2025-01-01  quarta-feira  19:00:00  SC  153  117,8
# 3  1468199   2025-01-02  quinta-feira  07:15:00  PB  230  105,6
# 4  1468477   2025-01-02  quinta-feira  13:20:00  ES  262   73,2
#
#            municipio                            causa_acidente  \
# 0              TAPES            Ausência de reação do condutor
# 1             MURIAE                   Velocidade Incompatível
# 2          CONCORDIA            Ausência de reação do condutor
# 3            MOGEIRO                         Condutor Dormindo
# 4  MARECHAL FLORIANO  Reação tardia ou ineficiente do condutor
#
#                tipo_acidente classificacao_acidente     fase_dia  sentido_via  \
# 0  Saída de leito carroçável    Com Vítimas Feridas    Pleno dia  Decrescente
# ...

# %%
df.isna().sum()
# Out:
# pesid                       0
# data_inversa                0
# dia_semana                  0
# horario                     0
# uf                          0
# br                          0
# km                          0
# municipio                   0
# causa_acidente              0
# tipo_acidente               0
# classificacao_acidente      0
# fase_dia                    0
# sentido_via                 0
# condicao_metereologica      0
# tipo_pista                  0
# tracado_via                 0
# uso_solo                    0
# id_veiculo                  0
# tipo_veiculo              518
# marca                       0
# ano_fabricacao_veiculo      0
# tipo_envolvido            108
# estado_fisico             108
# idade                       0
# sexo                      108
# ilesos                      0
# feridos_leves               0
# feridos_graves              0
# mortos                      0
# latitude                    0
# longitude                   0
# ...

# %%
df['sexo'] = df['sexo'].fillna('Não Informado')

# %%
df.loc[df['condicao_metereologica'] == 'Ignorado'].head(5)
# Out:
#        pesid data_inversa     dia_semana   horario  uf   br     km  \
# 45   1471327   2025-01-08   quarta-feira  05:30:00  MG  116  453,5
# 82   1472334   2025-01-10    sexta-feira  04:40:00  MG  262  110,2
# 159  1476699   2025-01-17    sexta-feira  21:30:00  MA  226    108
# 160  1476787   2025-01-18         sábado  03:00:00  MG  381    482
# 285  1482810   2025-01-27  segunda-feira  18:40:00  MG  153    114
#
#              municipio                                     causa_acidente  \
# 45   ENGENHEIRO CALDAS  Acessar a via sem observar a presença dos outr...
# 82           RIO CASCA                            Velocidade Incompatível
# 159             CAXIAS                     Ausência de reação do condutor
# 160              BETIM                     Ausência de reação do condutor
# 285              PRATA               Demais falhas mecânicas ou elétricas
#
#                  tipo_acidente classificacao_acidente     fase_dia  \
# ...
